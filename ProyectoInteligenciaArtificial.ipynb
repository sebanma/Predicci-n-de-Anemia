# %% [markdown]
# # **PROYECTO DE CLASE**

# %% [markdown]
# ![Banner Anemia.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # RESUMEN:
# Este conjunto de datos contiene registros importantes para llegar a la detección correcta de la enfermedad Anemia. Conjunto de datos de anemia que contiene atributos Género, Hemoglobina, MCHC, MCV, MCH y Resultados. Este conjunto de datos se utiliza para predecir si es probable que un paciente sufra anemia. Se utilizará el algoritmo clasificador binario de aprendizaje automático.
#
# Género: 0 - masculino, 1 - femenino
# Hemoglobina: la hemoglobina es una proteína en sus glóbulos rojos que transporta oxígeno a los órganos y tejidos de su cuerpo y transporta dióxido de carbono desde sus órganos y tejidos de regreso a sus pulmones.
# MCH: MCH es la abreviatura de "hemoglobina corpuscular media". Es la cantidad promedio en cada uno de sus glóbulos rojos de una proteína llamada hemoglobina, que transporta oxígeno por todo el cuerpo.
# MCHC: MCHC significa concentración de hemoglobina corpuscular media. Es una medida de la concentración promedio de hemoglobina dentro de un solo glóbulo rojo.
# MCV: MCV significa volumen corpuscular medio. Un análisis de sangre MCV mide el tamaño promedio de sus glóbulos rojos.
# Resultados: 0- no anémico, 1-anémico

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eba2d47b-e432-4cfc-9c9c-9a0b844ea969" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eba2d47b-e432-4cfc-9c9c-9a0b844ea969">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn import preprocessing
pd.__version__
# Out:
# '1.3.5'

# %%
data_anemia = pd.read_csv('anemia.csv')
print(data_anemia)
# Out:
#       Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0          1        14.9  22.7  29.1  83.7       0
# 1          0        15.9  25.4  28.3  72.0       0
# 2          0         9.0  21.5  29.6  71.2       1
# 3          0        14.9  16.0  31.4  87.5       0
# 4          1        14.7  22.0  28.2  99.5       0
# ...      ...         ...   ...   ...   ...     ...
# 1416       0        10.6  25.4  28.2  82.9       1
# 1417       1        12.1  28.3  30.4  86.9       1
# 1418       1        13.1  17.7  28.1  80.7       1
# 1419       0        14.3  16.2  29.5  95.2       0
# 1420       0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %% [markdown]
# # **MEDIDAS DE TENDENCIA CENTRAL**

# %% [markdown]
# ![882f0cf636f6e80c6c295895ddec4daa.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **MEDIA:**

# %% [markdown]
# ![mediaaa.png](data:image/png;base64,...)

# %%
data_anemia = pd.read_csv('anemia.csv')
genero = data_anemia.Gender
hemoglobina = data_anemia.Hemoglobin
mch = data_anemia.MCH
mchc= data_anemia.MCHC
mcv = data_anemia.MCV
resultado = data_anemia.Result

print('Genero:' + ' ' + str(np.mean(genero)))
print('hemoglobina:' + ' ' + str(np.mean(hemoglobina)))
print('MCH:' + ' ' + str(np.mean(mch)))
print('MCHC:' + ' ' + str(np.mean(mchc)))
print('MCV:' + ' ' + str(np.mean(mcv)))
print('Resultado:' + ' ' +  str(np.mean(resultado)))
# Out:
# Genero: 0.5207600281491908
# hemoglobina: 13.412737508796623
# MCH: 22.90562983814215
# MCHC: 30.251231527093594
# MCV: 85.5237860661506
# Resultado: 0.4363124560168895

# %% [markdown]
# **DESCRIPCIÓN:**La media es una medida de tendencia central  la cual es la suma de datos sobre el número total de datos, también conocida como promedio (se realiza con datos de carácter cuantitativo), en este caso contamos con la media de 6 columnas con este tipo de datos.

# %% [markdown]
# **MODA**

# %% [markdown]
# ![modaaaa.png](data:image/png;base64,...)

# %%
import statistics as stat

print('Genero:' + ' ' + str(stat.mode(genero)))
print('hemoglobina:' + ' ' + str(stat.mode(hemoglobina)))
print('MCH:' + ' ' + str(stat.mode(mch)))
print('MCHC:' + ' ' + str(stat.mode(mchc)))
print('Resultado:' + ' ' +  str(stat.mode(resultado)))
# Out:
# Genero: 1
# hemoglobina: 11.5
# MCH: 24.3
# MCHC: 32.2
# Resultado: 0

# %% [markdown]
# **MEDIANA:**

# %% [markdown]
# ![mediana.png](data:image/png;base64,...)

# %%
print('Genero:' + ' ' + str(np.median(genero)))
print('hemoglobina:' + ' ' + str(np.median(hemoglobina)))
print('MCH:' + ' ' + str(np.median(mch)))
print('MCHC:' + ' ' + str(np.median(mchc)))
print('MCV:' + ' ' + str(np.median(mcv)))
print('Resultado:' + ' ' +  str(np.median(resultado)))
# Out:
# Genero: 1.0
# hemoglobina: 13.2
# MCH: 22.7
# MCHC: 30.4
# MCV: 85.3
# Resultado: 0.0

# %% [markdown]
# **DESVIACIÓN ESTANDAR:**

# %%
print('Genero:' + ' ' + str(np.std(genero)))
print('hemoglobina:' + ' ' + str(np.std(hemoglobina)))
print('MCH:' + ' ' + str(np.std(mch)))
print('MCHC:' + ' ' + str(np.std(mchc)))
print('MCV:' + ' ' + str(np.std(mcv)))
print('Resultado:' + ' ' +  str(np.std(resultado)))
# Out:
# Genero: 0.4995688353282707
# hemoglobina: 1.9738507735407576
# MCH: 3.9679783504337336
# MCHC: 1.4004046727969548
# MCV: 9.633309852426269
# Resultado: 0.49592730993705053

# %% [markdown]
# # **REPRESENTACIONES GRAFICAS:**

# %% [markdown]
# #Diagrama de Barras

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data_anemia[['Gender','Result']].groupby(['Gender']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Tienen anemia vs Género')
sns.countplot('Gender',hue='Result',data=data_anemia,ax=ax[1])
ax[1].set_title('Genero:Tienen Anemia vs No tienen Anemia')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data_anemia['Result'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('had anemia')
ax[0].set_ylabel('')
sns.countplot('Result',data=data_anemia,ax=ax[1])
ax[1].set_title('had anemia')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,5))
data_anemia_len=data_anemia[data_anemia['Result']==1]['Hemoglobin'].value_counts()
ax1.hist(data_anemia_len,color='red')
ax1.set_title('Tienen anemia')
data_anemia_len=data_anemia[data_anemia['Result']==0]['Hemoglobin'].value_counts()
ax2.hist(data_anemia_len,color='green')
ax2.set_title('No tienen anemia')
fig.suptitle('Niveles de hemoglobina')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,5))
data_anemia_len=data_anemia[data_anemia['Result']==1]['MCH'].value_counts()
ax1.hist(data_anemia_len,color='red')
ax1.set_title('Tienen anemia')
data_anemia_len=data_anemia[data_anemia['Result']==0]['MCH'].value_counts()
ax2.hist(data_anemia_len,color='green')
ax2.set_title('No tienen anemia')
fig.suptitle('Niveles de MCH')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,5))
data_anemia_len=data_anemia[data_anemia['Result']==1]['MCHC'].value_counts()
ax1.hist(data_anemia_len,color='red')
ax1.set_title('Tienen anemia')
data_anemia_len=data_anemia[data_anemia['Result']==0]['MCHC'].value_counts()
ax2.hist(data_anemia_len,color='green')
ax2.set_title('No tienen anemia')
fig.suptitle('Niveles de MCHC')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,5))
data_anemia_len=data_anemia[data_anemia['Result']==1]['MCV'].value_counts()
ax1.hist(data_anemia_len,color='red')
ax1.set_title('Tienen anemia')
data_anemia_len=data_anemia[data_anemia['Result']==0]['MCV'].value_counts()
ax2.hist(data_anemia_len,color='green')
ax2.set_title('No tienen anemia')
fig.suptitle('Niveles de MCV')
plt.show()

# %%
sns.heatmap(data_anemia.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf() 
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# # **Clasificación de componentes teniendo en cuenta ciertos valores**

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %%
#@title **code** División de los datos en conjuntos de prueba y entrenamiento
train,test=train_test_split(data_anemia,test_size=0.3,random_state=0,stratify=data_anemia['Result'])
train_X=train[train.columns[:-1]]
train_Y=train[train.columns[-1:]]
test_X=test[test.columns[:-1]]
test_Y=test[test.columns[-1:]]
X=data_anemia[data_anemia.columns[:-1]]
Y=data_anemia['Result']
len(train_X), len(train_Y), len(test_X), len(test_Y)
# Out:
# (994, 994, 427, 427)

# %% [markdown]
# #**GaussianNB**

# %%
model=GaussianNB()
model.fit(train_X,train_Y)
prediction6=model.predict(test_X)
print('La precisión de GausianNB es:', metrics.accuracy_score(prediction6,test_Y))
# Out:
# La precisión de GausianNB es: 0.955503512880562

# %% [markdown]
# #**Decision Tree classifier (Aplicacion)**

# %%
model=DecisionTreeClassifier()
model.fit(train_X,train_Y)
prediction4=model.predict(test_X)
print('La precisión del árbol de decisión es',metrics.accuracy_score(prediction4,test_Y))
# Out:
# La precisión del árbol de decisión es 1.0

# %% [markdown]
# # **Random Forest classifier (RFC)**

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(train_X,train_Y)
prediction7=model.predict(test_X)
print('La precisión de los Random Forests es',metrics.accuracy_score(prediction7,test_Y))
# Out:
# La precisión de los Random Forests es 1.0

# %% [markdown]
# #**Support vector machine (Aplicacion)**

# %%
model=svm.SVC(kernel='linear',C=0.1,gamma=0.1)
model.fit(train_X,train_Y)
prediction2=model.predict(test_X)
print('La precisión para SVM lineal es',metrics.accuracy_score(prediction2,test_Y))
# Out:
# La precisión para SVM lineal es 0.9859484777517564

# %% [markdown]
# #**Validación y comparación de los metódos de Clasificación**

# %%
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
kfold = KFold(n_splits=10) # k=10, split the data into 10 equal parts
cv_mean=[]
accuracy=[]
std=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree','Gaussian NB','Random Forest']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),KNeighborsClassifier(n_neighbors=9),DecisionTreeClassifier(),GaussianNB(),RandomForestClassifier(n_estimators=100)]
for i in models:
    model = i
    cv_result = cross_val_score(model,X,Y, cv = kfold,scoring = "accuracy")
    cv_result=cv_result
    cv_mean.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2=pd.DataFrame({'CV Mean':cv_mean,'Std':std},index=classifiers)       
new_models_dataframe2
# Out:
#                       CV Mean       Std
# Linear Svm           0.994366  0.008213
# Radial Svm           0.902191  0.019214
# Logistic Regression  0.991554  0.007586
# KNN                  0.900079  0.028450
# Decision Tree        1.000000  0.000000
# Gaussian NB          0.938782  0.023560
# Random Forest        1.000000  0.000000

# %%
new_models_dataframe2['CV Mean'].plot.barh(width=0.8)
plt.title('Promedio de presición CV Mean ')
fig=plt.gcf()
fig.set_size_inches(8,5)
plt.show()

# %%
f,ax=plt.subplots(3,3,figsize=(12,10))
y_pred = cross_val_predict(svm.SVC(kernel='rbf'),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[0,0],annot=True,fmt='2.0f')
ax[0,0].set_title('Matrix for rbf-SVM')
y_pred = cross_val_predict(svm.SVC(kernel='linear'),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[0,1],annot=True,fmt='2.0f')
ax[0,1].set_title('Matrix for Linear-SVM')
y_pred = cross_val_predict(KNeighborsClassifier(n_neighbors=5),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[0,2],annot=True,fmt='2.0f')
ax[0,2].set_title('Matrix for KNN')
y_pred = cross_val_predict(RandomForestClassifier(n_estimators=100),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[1,0],annot=True,fmt='2.0f')
ax[1,0].set_title('Matrix for Random-Forests')
y_pred = cross_val_predict(LogisticRegression(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[1,1],annot=True,fmt='2.0f')
ax[1,1].set_title('Matrix for Logistic Regression')
y_pred = cross_val_predict(DecisionTreeClassifier(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[1,2],annot=True,fmt='2.0f')
ax[1,2].set_title('Matrix for Decision Tree')
y_pred = cross_val_predict(GaussianNB(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,y_pred),ax=ax[2,0],annot=True,fmt='2.0f')
ax[2,0].set_title('Matrix for Gaussian NB')
plt.subplots_adjust(hspace=0.2,wspace=0.2)
plt.show()

# %%
from sklearn.ensemble import VotingClassifier
ensemble_lin_rbf=VotingClassifier(estimators=[('KNN',KNeighborsClassifier(n_neighbors=5)),
                                              ('RBF',svm.SVC(probability=True,kernel='rbf',C=0.5,gamma=0.1)),
                                              ('RFor',RandomForestClassifier(n_estimators=500,random_state=0)),
                                              ('LR',LogisticRegression(C=0.05)),
                                              ('DT',DecisionTreeClassifier(random_state=0)),
                                              ('NB',GaussianNB()),
                                              ('svm',svm.SVC(kernel='linear',probability=True))
                                             ], 
voting='soft').fit(train_X,train_Y)
print('La precisión para el modelo ensamblado es:',ensemble_lin_rbf.score(test_X,test_Y))
cross=cross_val_score(ensemble_lin_rbf,X,Y, cv = 10,scoring = "accuracy")
print('La puntuación media de la validación cruzada :',cross.mean())
# Out:
# La precisión para el modelo ensamblado es: 1.0
# La puntuación media de la validación cruzada : 0.995774647887324

# %% [markdown]
# ![44357_0714817001606176755.jpg](data:image/jpeg;base64,...)
